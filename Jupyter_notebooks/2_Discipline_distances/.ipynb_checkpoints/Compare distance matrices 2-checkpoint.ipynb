# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from ast import literal_eval

# %%
# load distance matrix M (between disciplines)
path = r'C:\Users\lucp11051\Documents\Jupyter_notebooks\2_Discipline_distances/'
cur_path = os.getcwd()

count_type = 'citation_flow'
data = 'matrix15'

filename ='dm_corr_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
cos1 = np.loadtxt(new_path)
filename ='dm_cosine_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
corr1 = np.loadtxt(new_path)

count_type = 'disc_in_a_person'
data = 'pub_2014'

filename ='dm_corr_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
cos2 = np.loadtxt(new_path)
filename ='dm_cosine_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
corr2 = np.loadtxt(new_path)
filename ='dm_jaccard_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
jac2 = np.loadtxt(new_path)
filename ='dm_jaccard_sqrt_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
jacsq2 = np.loadtxt(new_path)
filename ='dm_nameless_sqrt_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
nameless2 = np.loadtxt(new_path)

count_type = 'colab'
data = 'projects'

filename ='dm_corr_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
cos3 = np.loadtxt(new_path)
filename ='dm_cosine_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
corr3 = np.loadtxt(new_path)
filename ='dm_jaccard_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
jac3 = np.loadtxt(new_path)
filename ='dm_jaccard_sqrt_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
jacsq3 = np.loadtxt(new_path)

filename ='dm_corr_pai_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
cos_pai3 = np.loadtxt(new_path)
filename ='dm_cosine_pai_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
corr_pai3 = np.loadtxt(new_path)
filename ='dm_jaccard_pai_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
jac_pai3 = np.loadtxt(new_path)
filename ='dm_jaccard_sqrt_pai_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
jacsq_pai3 = np.loadtxt(new_path)

# %%
# VODS disciplines codes:
discipline_codes=['0101',
'0102',
'0103',
'0104',
'0105',
'0106',
'0107',
'0199',
'0201',
'0202',
'0203',
'0204',
'0205',
'0206',
'0207',
'0208',
'0299',
'0301',
'0302',
'0303',
'0304',
'0305',
'0306',
'0399',
'0401',
'0402',
'0499',
'0501',
'0502',
'0503',
'0504',
'0505',
'0506',
'0507',
'0508',
'0599',
'0601',
'0602',
'0603',
'0604',
'0699',
'0700']

# %%
from ast import literal_eval
level1=[]
for code in discipline_codes:
    level1 =level1+ [code[:2]]  
level1
# Out:
# ['01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '03',
#  '03',
#  '03',
#  '03',
#  '03',
#  '03',
#  '03',
#  '04',
#  '04',
#  '04',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '06',
#  '06',
#  '06',
#  '06',
#  '06',
#  '07']

# %%
flat_dms=[cos1.flatten(), cos2.flatten(), cos3.flatten(), corr1.flatten(), corr2.flatten(), corr3.flatten(), jac2.flatten(), jac3.flatten(), \
        jacsq2.flatten(), jacsq3.flatten(), nameless2.flatten() ]
cols=['cos1', 'cos2', 'cos3', 'corr1', 'corr2', 'corr3', 'jac2', 'jac3', 'jacsq2', 'jacsq3', 'nameless2']
real_col=[ 'cos2', 'cos3', 'corr2', 'corr3', 'jac2', 'jac3', 'level1']
df= pd.DataFrame(np.transpose(flat_dms),columns=cols)
df['codes']= 42*discipline_codes
df['level1']=42*level1
df
# Out:
#           cos1      cos2      cos3     corr1     corr2     corr3      jac2  \
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.122823  0.339705  0.116256  0.232852  0.596311  0.176218  0.884693
# 2     0.401578  0.414070  0.380994  0.753485  0.757880  0.604441  0.941365
# 3     0.480835  0.543117  0.520363  0.892879  0.969794  0.785131  0.998641
# 4     0.511521  0.386251  0.449002  0.957653  0.680042  0.649312  0.931135
# ...        ...       ...       ...       ...       ...       ...       ...
# 1759  1.000000  0.518432  0.550547  1.000000  0.972416  0.893993  0.999476
# 1760  1.000000  0.524578  0.557759  1.000000  0.987520  0.903772  1.000000
# 1761  1.000000  0.531242  0.405680  1.000000  0.982244  0.604417  1.000000
# 1762  1.000000  0.520288  0.507878  1.000000  0.959915  0.781780  0.998436
# 1763  0.000000  0.000000  0.000000  0.000000 -0.000000  0.000000  0.000000
#
#           jac3    jacsq2    jacsq3  nameless2 codes level1
# ...

# %%
flat_dms=[ cos2.flatten(), cos3.flatten(), corr2.flatten(), corr3.flatten(), cos_pai3.flatten(), corr_pai3.flatten()]
cols=[ 'cos2', 'cos3', 'corr2', 'corr3', 'cos_pai3', 'corr_pai3']
real_col=['cos2', 'cos3', 'corr2', 'corr3', 'cos_pai3', 'corr_pai3', 'level1']
df_1= pd.DataFrame(np.transpose(flat_dms),columns=cols)
df_1['codes']= 42*discipline_codes
df_1['level1']=42*level1
df_1
# Out:
#           cos2      cos3     corr2     corr3  cos_pai3  corr_pai3 codes level1
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  -0.000000  0101     01
# 1     0.339705  0.116256  0.596311  0.176218  0.140984   0.206384  0102     01
# 2     0.414070  0.380994  0.757880  0.604441  0.343824   0.532145  0103     01
# 3     0.543117  0.520363  0.969794  0.785131  0.525973   0.754782  0104     01
# 4     0.386251  0.449002  0.680042  0.649312  0.459603   0.701992  0105     01
# ...        ...       ...       ...       ...       ...        ...   ...    ...
# 1759  0.518432  0.550547  0.972416  0.893993  0.527424   0.915007  0602     06
# 1760  0.524578  0.557759  0.987520  0.903772  0.538303   0.952814  0603     06
# 1761  0.531242  0.405680  0.982244  0.604417  0.466810   0.778730  0604     06
# 1762  0.520288  0.507878  0.959915  0.781780  0.509080   0.865357  0699     06
# 1763  0.000000  0.000000 -0.000000  0.000000  0.000000   0.000000  0700     07
#
# [1764 rows x 8 columns]

# %%
a_series = (df.iloc[:,0:9] != 0).any(axis=1)
new_df = df.loc[a_series]

# %%
a_series = (df_1.iloc[:,0:4] != 0).any(axis=1)
new_df_1 = df_1.loc[a_series]

# %%
new_df_1
# Out:
#           cos2      cos3     corr2     corr3  cos_pai3  corr_pai3 codes level1
# 1     0.339705  0.116256  0.596311  0.176218  0.140984   0.206384  0102     01
# 2     0.414070  0.380994  0.757880  0.604441  0.343824   0.532145  0103     01
# 3     0.543117  0.520363  0.969794  0.785131  0.525973   0.754782  0104     01
# 4     0.386251  0.449002  0.680042  0.649312  0.459603   0.701992  0105     01
# 5     0.524537  0.479145  0.928240  0.723272  0.510509   0.674236  0106     01
# ...        ...       ...       ...       ...       ...        ...   ...    ...
# 1758  0.519033  0.507602  0.968732  0.772171  0.487649   0.824261  0601     06
# 1759  0.518432  0.550547  0.972416  0.893993  0.527424   0.915007  0602     06
# 1760  0.524578  0.557759  0.987520  0.903772  0.538303   0.952814  0603     06
# 1761  0.531242  0.405680  0.982244  0.604417  0.466810   0.778730  0604     06
# 1762  0.520288  0.507878  0.959915  0.781780  0.509080   0.865357  0699     06
#
# [1722 rows x 8 columns]

# %%
sns.set(rc={"figure.figsize": (9,6)})
corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
sns.set(rc={"figure.figsize": (9,6)})
corrMatrix = df_1.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
list(corrMatrix.index)
# Out:
# ['cos2', 'cos3', 'corr2', 'corr3', 'cos_pai3', 'corr_pai3']

# %%
sns.pairplot(df)

# %%
sns.pairplot(df_1)

# %%
sns.pairplot(df[real_col], hue = 'level1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-4cce10f9f7b7> in <module>
# ----> 1 sns.pairplot(df[real_col], hue = 'level1')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(df, x='cos2', binwidth=0.02, ax=axes[0,0])
sns.histplot(df, x='cos3', binwidth=0.02, ax=axes[0,1])
sns.histplot(df, x='corr2', binwidth=0.02, ax=axes[1,0])
sns.histplot(df, x='corr3', binwidth=0.02, ax=axes[1,1])
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

axes[0,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(df['cos2'].median(),np.std(df['cos2'])))
axes[0,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(df['cos3'].median(),np.std(df['cos3'])))
axes[1,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(df['corr2'].median(),np.std(df['corr2'])))
axes[1,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(df['corr3'].median(),np.std(df['corr3'])))
plt.show()

# %%
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(new_df, x='cos2', binwidth=0.02, ax=axes[0,0])
sns.histplot(new_df, x='cos3', binwidth=0.02, ax=axes[0,1])
sns.histplot(new_df, x='corr2', binwidth=0.02, ax=axes[1,0])
sns.histplot(new_df, x='corr3', binwidth=0.02, ax=axes[1,1])
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

axes[0,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df['cos2'].median(),np.std(new_df['cos2'])))
axes[0,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df['cos3'].median(),np.std(new_df['cos3'])))
axes[1,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df['corr2'].median(),np.std(new_df['corr2'])))
axes[1,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df['corr3'].median(),np.std(new_df['corr3'])))
plt.show()

# %%
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(new_df_1, x='cos_pai3', binwidth=0.02, ax=axes[0,0])
sns.histplot(new_df_1, x='cos3', binwidth=0.02, ax=axes[0,1])
sns.histplot(new_df_1, x='corr_pai3', binwidth=0.02, ax=axes[1,0])
sns.histplot(new_df_1, x='corr3', binwidth=0.02, ax=axes[1,1])
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

axes[0,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df_1['cos_pai3'].median(),np.std(new_df_1['cos_pai3'])))
axes[0,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df_1['cos3'].median(),np.std(new_df_1['cos3'])))
axes[1,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df_1['corr_pai3'].median(),np.std(new_df_1['corr_pai3'])))
axes[1,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df_1['corr3'].median(),np.std(new_df_1['corr3'])))
plt.show()

# %%
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(df, x='corr1', binwidth=0.02, ax=axes[0,0])
sns.histplot(df, x='nameless2', binwidth=0.02, ax=axes[0,1])
sns.histplot(df, x='jacsq2', binwidth=0.02, ax=axes[1,0])
sns.histplot(df, x='jacsq3', binwidth=0.02, ax=axes[1,1])
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)
plt.show()

# %%
list(new_df.columns)

# %%
from scipy import stats
spearmanMatrix=stats.spearmanr(new_df)
data=spearmanMatrix[0][:-2,:-2]
sns.heatmap(pd.DataFrame(data, index =list(new_df.columns)[:-2], columns= list(new_df.columns)[:-2]), annot=True)

# %%
from scipy import stats
spearmanMatrix=stats.spearmanr(new_df_1)
data=spearmanMatrix[0][:-2,:-2]
sns.heatmap(pd.DataFrame(data, index =list(new_df_1.columns)[:-2], columns= list(new_df_1.columns)[:-2]), annot=True)

# %%
sns.kdeplot(data=df.iloc[start*42:end*42+42,:], x="corr3", hue = 'level1', fill=False)

# %%
code = '0699'
if len(code)==2:
    start=np.where(np.array(level1) == code)[0][0]
    end=np.where(np.array(level1) == code)[0][-1]
elif len(code)==4:
    start=np.where(np.array(discipline_codes) == code)[0][0]
    end=np.where(np.array(discipline_codes) == code)[0][-1]
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(df.iloc[start*42:end*42+42,:], x='cos2', binwidth=0.02, ax=axes[0,0], element="step",  hue = 'level1', legend= False)
sns.histplot(df.iloc[start*42:end*42+42,:], x='cos3', binwidth=0.02, ax=axes[0,1], element="step",  hue = 'level1')
sns.histplot(df.iloc[start*42:end*42+42,:], x='corr2', binwidth=0.02, ax=axes[1,0], element="step",  hue = 'level1', legend= False)
sns.histplot(df.iloc[start*42:end*42+42,:], x='corr3', binwidth=0.02, ax=axes[1,1], element="step",  hue = 'level1', legend= False)
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

plt.show()

# %%
code = '0199'
if len(code)==2:
    start=np.where(np.array(level1) == code)[0][0]
    end=np.where(np.array(level1) == code)[0][-1]
elif len(code)==4:
    start=np.where(np.array(discipline_codes) == code)[0][0]
    end=np.where(np.array(discipline_codes) == code)[0][-1]
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(df_1.iloc[start*42:end*42+42,:], x='cos_pai3', binwidth=0.02, ax=axes[0,0], element="step",  hue = 'level1', legend= False)
sns.histplot(df_1.iloc[start*42:end*42+42,:], x='cos3', binwidth=0.02, ax=axes[0,1], element="step",  hue = 'level1')
sns.histplot(df_1.iloc[start*42:end*42+42,:], x='corr_pai3', binwidth=0.02, ax=axes[1,0], element="step",  hue = 'level1', legend= False)
sns.histplot(df_1.iloc[start*42:end*42+42,:], x='corr3', binwidth=0.02, ax=axes[1,1], element="step",  hue = 'level1', legend= False)
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

plt.show()

# %%
code = '0199'
if len(code)==2:
    start=np.where(np.array(level1) == code)[0][0]
    end=np.where(np.array(level1) == code)[0][-1]
elif len(code)==4:
    start=np.where(np.array(discipline_codes) == code)[0][0]
    end=np.where(np.array(discipline_codes) == code)[0][-1]
diff_df= pd.DataFrame()

diff_df['cos_pai3 - cos3']=df_1.iloc[start*42:end*42+42,:]['cos_pai3']-df_1.iloc[start*42:end*42+42,:]['cos3']
diff_df['corr_pai3 - corr3']=df_1.iloc[start*42:end*42+42,:]['corr_pai3']-df_1.iloc[start*42:end*42+42,:]['corr3']
diff_df['cos3 - corr3']=df_1.iloc[start*42:end*42+42,:]['cos3']-df_1.iloc[start*42:end*42+42,:]['corr3']
diff_df['cos_pai3 - corr_pai3']=df_1.iloc[start*42:end*42+42,:]['cos_pai3']-df_1.iloc[start*42:end*42+42,:]['corr_pai3']
diff_df.index = df_1.iloc[start*42:end*42+42,:]['codes']
diff_df

# %%
diff_df.mean(), diff_df.mad(), diff_df.std()
