# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from ast import literal_eval

# %%
# load distance matrix M (between disciplines)
path = r'C:\Users\lucp11051\Documents\Jupyter_notebooks\2_Discipline_distances/'
cur_path = os.getcwd()



count_type = 'colab'
data = 'projects'


filename ='sm_cosine_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
cos = np.loadtxt(new_path)

filename ='sm_cosine1_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
cos1 = np.loadtxt(new_path)


filename ='sm_sdc_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
sdc = np.loadtxt(new_path)
filename ='sm_ochiai_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
ochiai = np.loadtxt(new_path)
filename ='sm_pai_' + count_type + '_' + data+  '.txt'
new_path = os.path.relpath('..\\2_Discipline_distances/'+filename, cur_path)
pai = np.loadtxt(new_path)

# %%
def lower_triangle(matrix):
    lower=[]
    for i in range(len(matrix)):
        for j in range(i):
            lower=lower+[matrix[i,j]]
    return lower + list(np.diag(matrix))

# %%
# VODS disciplines codes:
discipline_codes=['0101',
'0102',
'0103',
'0104',
'0105',
'0106',
'0107',
'0199',
'0201',
'0202',
'0203',
'0204',
'0205',
'0206',
'0207',
'0208',
'0299',
'0301',
'0302',
'0303',
'0304',
'0305',
'0306',
'0399',
'0401',
'0402',
'0499',
'0501',
'0502',
'0503',
'0504',
'0505',
'0506',
'0507',
'0508',
'0599',
'0601',
'0602',
'0603',
'0604',
'0699',
'0700']

# %%
from ast import literal_eval
level1=[]
for code in discipline_codes:
    level1 =level1+ [code[:2]]  
level1
# Out:
# ['01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '01',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '02',
#  '03',
#  '03',
#  '03',
#  '03',
#  '03',
#  '03',
#  '03',
#  '04',
#  '04',
#  '04',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '05',
#  '06',
#  '06',
#  '06',
#  '06',
#  '06',
#  '07']

# %%
lower_t=[ lower_triangle(cos1), lower_triangle(sdc), lower_triangle(ochiai),lower_triangle(pai)]
cols=['Cosine', 'SDC', 'Ochiai', 'AS']

df= pd.DataFrame(np.transpose(lower_t),columns=cols)
# Out:
#        Cosine       SDC    Ochiai         AS
# 0    0.273759  0.121072  0.128759   5.559302
# 1    0.119549  0.052171  0.053759   2.607139
# 2    0.069800  0.025694  0.025900   0.924709
# 3    0.030314  0.006222  0.006475   0.248467
# 4    0.034240  0.009644  0.009523   0.269052
# ..        ...       ...       ...        ...
# 898  1.000000  1.000000  1.000000  19.709027
# 899  1.000000  1.000000  1.000000  26.416149
# 900  1.000000  1.000000  1.000000  12.172928
# 901  1.000000  1.000000  1.000000  14.941913
# 902  1.000000  1.000000  1.000000  30.123452
#
# [903 rows x 4 columns]

# %%
1/42
# Out:
# 0.023809523809523808

# %%
1/42**2
# Out:
# 0.0005668934240362812

# %%
df[:861].mean(),df[:861].median()
# Out:
# (Cosine    0.056504
#  SDC       0.015402
#  Ochiai    0.016831
#  AS        0.904814
#  dtype: float64,
#  Cosine    0.035261
#  SDC       0.006069
#  Ochiai    0.006860
#  AS        0.392329
#  dtype: float64)

# %%
df.mean(),df.median()
# Out:
# (Cosine    0.100387
#  SDC       0.061197
#  Ochiai    0.062559
#  AS        1.381923
#  dtype: float64,
#  Cosine    0.038359
#  SDC       0.006465
#  Ochiai    0.007494
#  AS        0.440892
#  dtype: float64)

# %%
sns.set(rc={"figure.figsize": (9,6)})
corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
from scipy import stats
spearmanMatrix=stats.spearmanr(df)
data=spearmanMatrix[0]
sns.heatmap(pd.DataFrame(data, index =list(df.columns), columns= list(df.columns)), annot=True)
# Out:
# <AxesSubplot:>

# %%
from scipy import stats
spearmanMatrix=stats.spearmanr(df)
data=spearmanMatrix[0]
sns.heatmap(pd.DataFrame(data, index =list(df.columns), columns= list(df.columns)), annot=True)
# Out:
# <AxesSubplot:>

# %%
861*['cos']+861*['sdc']+861*['ochiai']+861*['pai']
# Out:
# ['cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'cos',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  'sdc',
#  ...]

# %%
data=[lower_triangle(cos1)+ lower_triangle(sdc)+lower_triangle(ochiai),\
      861*['cos1']+861*['sdc']+861*['ochiai']]
cols=['Similarity', 'Measure']

df1= pd.DataFrame(np.transpose(data),columns=cols)
df1=df1.astype({'Similarity': 'float64'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12216\836196787.py in <module>
#       3 cols=['Similarity', 'Measure']
#       4
# ----> 5 df1= pd.DataFrame(np.transpose(data),columns=cols)
#       6 df1=df1.astype({'Similarity': 'float64'})
#
# c:\users\lucp11046\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     676                     dtype=dtype,
#     677                     copy=copy,
# --> 678                     typ=manager,
#     679                 )
#     680
#
# c:\users\lucp11046\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# c:\users\lucp11046\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (2, 1), indices imply (2, 2)

# %%
a=0.92
np.quantile(df['Cosine'][0:861], a),np.quantile(df['SDC'][0:861], a),np.quantile(df['Ochiai'][0:861], a)
# Out:
# (0.15761977500000007, 0.04711723227698033, 0.05365312365098846)

# %%
from scipy import stats
stats.percentileofscore(df['Cosine'][0:861], 0.05), stats.percentileofscore(df['SDC'][0:861], 0.05), stats.percentileofscore(df['Ochiai'][0:861], 0.05)
# Out:
# (63.41463414634146, 92.6829268292683, 90.70847851335657)

# %%
# sns.displot(data=df1, x="Similarity", hue="Measure", kind="kde")

# %%
data=[lower_triangle(cos1)+ lower_triangle(sdc)+lower_triangle(ochiai),\
      861*['cos1']+861*['sdc']+861*['ochiai']]
cols=['Similarity', 'Measure']

df1= pd.DataFrame(np.transpose(data),columns=cols)
df1=df1.astype({'Similarity': 'float64'})

sns.histplot(data=df1, x="Similarity", hue="Measure")
# Out:
# <AxesSubplot:xlabel='Similarity', ylabel='Count'>

# %%
data=[lower_triangle(cos1)+ lower_triangle(sdc)+lower_triangle(ochiai)+lower_triangle(pai),\
      len(lower_triangle(cos1))*['Cosine']+len(lower_triangle(cos1))*['SDC']+len(lower_triangle(cos1))*['Ochiai']+len(lower_triangle(pai))*['AS']]

# data=[lower_triangle(cos1)+ lower_triangle(sdc)+lower_triangle(ochiai),\
#       len(lower_triangle(cos1))*['Cosine']+len(lower_triangle(cos1))*['SDC']+len(lower_triangle(cos1))*['Ochiai']]

cols=['Similarity', 'Measure']

df1= pd.DataFrame(np.transpose(data),columns=cols)
df1=df1.astype({'Similarity': 'float64'})

df1['Similarity'] = (df1['Similarity']-df1['Similarity'].min())/(df1['Similarity'].max()-df1['Similarity'].min())

g = sns.histplot(data=df1, x="Similarity", hue="Measure")
g.set_yscale("log")

# %%
df['AS'] = (df['AS']-df['AS'].min())/(df['AS'].max()-df['AS'].min())
sns.pairplot(df.iloc[:,:])

# %%
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,3)
sns.histplot(df, x='cos', binwidth=0.02, ax=axes[0,0])
sns.histplot(df, x='corr', binwidth=0.02, ax=axes[0,1])
sns.histplot(df, x='cos_pai', binwidth=0.02, ax=axes[1,0])
sns.histplot(df, x='corr_pai', binwidth=0.02, ax=axes[1,1])
sns.histplot(df, x='jacsq', binwidth=0.02, ax=axes[0,2])
sns.histplot(df, x='sdc', binwidth=0.02, ax=axes[1,2])
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

axes[0,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(df['cos2'].median(),np.std(df['cos2'])))
axes[0,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(df['cos3'].median(),np.std(df['cos3'])))
axes[1,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(df['corr2'].median(),np.std(df['corr2'])))
axes[1,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(df['corr3'].median(),np.std(df['corr3'])))
plt.show()

# %%
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(new_df, x='cos2', binwidth=0.02, ax=axes[0,0])
sns.histplot(new_df, x='cos3', binwidth=0.02, ax=axes[0,1])
sns.histplot(new_df, x='corr2', binwidth=0.02, ax=axes[1,0])
sns.histplot(new_df, x='corr3', binwidth=0.02, ax=axes[1,1])
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

axes[0,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df['cos2'].median(),np.std(new_df['cos2'])))
axes[0,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df['cos3'].median(),np.std(new_df['cos3'])))
axes[1,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df['corr2'].median(),np.std(new_df['corr2'])))
axes[1,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df['corr3'].median(),np.std(new_df['corr3'])))
plt.show()

# %%
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(new_df_1, x='cos_pai3', binwidth=0.02, ax=axes[0,0])
sns.histplot(new_df_1, x='cos3', binwidth=0.02, ax=axes[0,1])
sns.histplot(new_df_1, x='corr_pai3', binwidth=0.02, ax=axes[1,0])
sns.histplot(new_df_1, x='corr3', binwidth=0.02, ax=axes[1,1])
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

axes[0,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df_1['cos_pai3'].median(),np.std(new_df_1['cos_pai3'])))
axes[0,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df_1['cos3'].median(),np.std(new_df_1['cos3'])))
axes[1,0].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df_1['corr_pai3'].median(),np.std(new_df_1['corr_pai3'])))
axes[1,1].set_title('Median: {:.2f}, standard deviation {:.2f}'.format(new_df_1['corr3'].median(),np.std(new_df_1['corr3'])))
plt.show()

# %%
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(df, x='corr1', binwidth=0.02, ax=axes[0,0])
sns.histplot(df, x='nameless2', binwidth=0.02, ax=axes[0,1])
sns.histplot(df, x='jacsq2', binwidth=0.02, ax=axes[1,0])
sns.histplot(df, x='jacsq3', binwidth=0.02, ax=axes[1,1])
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)
plt.show()

# %%
list(new_df.columns)

# %%
from scipy import stats
spearmanMatrix=stats.spearmanr(new_df_1)
data=spearmanMatrix[0][:-2,:-2]
sns.heatmap(pd.DataFrame(data, index =list(new_df_1.columns)[:-2], columns= list(new_df_1.columns)[:-2]), annot=True)

# %%
sns.kdeplot(data=df.iloc[start*42:end*42+42,:], x="corr3", hue = 'level1', fill=False)

# %%
code = '0699'
if len(code)==2:
    start=np.where(np.array(level1) == code)[0][0]
    end=np.where(np.array(level1) == code)[0][-1]
elif len(code)==4:
    start=np.where(np.array(discipline_codes) == code)[0][0]
    end=np.where(np.array(discipline_codes) == code)[0][-1]
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(df.iloc[start*42:end*42+42,:], x='cos2', binwidth=0.02, ax=axes[0,0], element="step",  hue = 'level1', legend= False)
sns.histplot(df.iloc[start*42:end*42+42,:], x='cos3', binwidth=0.02, ax=axes[0,1], element="step",  hue = 'level1')
sns.histplot(df.iloc[start*42:end*42+42,:], x='corr2', binwidth=0.02, ax=axes[1,0], element="step",  hue = 'level1', legend= False)
sns.histplot(df.iloc[start*42:end*42+42,:], x='corr3', binwidth=0.02, ax=axes[1,1], element="step",  hue = 'level1', legend= False)
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

plt.show()

# %%
code = '0199'
if len(code)==2:
    start=np.where(np.array(level1) == code)[0][0]
    end=np.where(np.array(level1) == code)[0][-1]
elif len(code)==4:
    start=np.where(np.array(discipline_codes) == code)[0][0]
    end=np.where(np.array(discipline_codes) == code)[0][-1]
sns.set(rc={"figure.figsize": (12,8)})

fig,axes=plt.subplots(2,2)
sns.histplot(df_1.iloc[start*42:end*42+42,:], x='cos_pai3', binwidth=0.02, ax=axes[0,0], element="step",  hue = 'level1', legend= False)
sns.histplot(df_1.iloc[start*42:end*42+42,:], x='cos3', binwidth=0.02, ax=axes[0,1], element="step",  hue = 'level1')
sns.histplot(df_1.iloc[start*42:end*42+42,:], x='corr_pai3', binwidth=0.02, ax=axes[1,0], element="step",  hue = 'level1', legend= False)
sns.histplot(df_1.iloc[start*42:end*42+42,:], x='corr3', binwidth=0.02, ax=axes[1,1], element="step",  hue = 'level1', legend= False)
ymax= max([axes[0,0].get_ylim()[1], axes[0,1].get_ylim()[1], axes[1,0].get_ylim()[1], axes[1,1].get_ylim()[1]])

axes[0,0].set_ylim(0,ymax)
axes[0,1].set_ylim(0,ymax)
axes[1,0].set_ylim(0,ymax)
axes[1,1].set_ylim(0,ymax)
axes[0,0].set_xlim(0,1)
axes[0,1].set_xlim(0,1)
axes[1,0].set_xlim(0,1)
axes[1,1].set_xlim(0,1)

plt.show()

# %%
code = '0199'
if len(code)==2:
    start=np.where(np.array(level1) == code)[0][0]
    end=np.where(np.array(level1) == code)[0][-1]
elif len(code)==4:
    start=np.where(np.array(discipline_codes) == code)[0][0]
    end=np.where(np.array(discipline_codes) == code)[0][-1]
diff_df= pd.DataFrame()

diff_df['cos_pai3 - cos3']=df_1.iloc[start*42:end*42+42,:]['cos_pai3']-df_1.iloc[start*42:end*42+42,:]['cos3']
diff_df['corr_pai3 - corr3']=df_1.iloc[start*42:end*42+42,:]['corr_pai3']-df_1.iloc[start*42:end*42+42,:]['corr3']
diff_df['cos3 - corr3']=df_1.iloc[start*42:end*42+42,:]['cos3']-df_1.iloc[start*42:end*42+42,:]['corr3']
diff_df['cos_pai3 - corr_pai3']=df_1.iloc[start*42:end*42+42,:]['cos_pai3']-df_1.iloc[start*42:end*42+42,:]['corr_pai3']
diff_df.index = df_1.iloc[start*42:end*42+42,:]['codes']
diff_df

# %%
diff_df.mean(), diff_df.mad(), diff_df.std()
