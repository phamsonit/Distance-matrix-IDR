# %%
import pandas as pd
import numpy as np

# %%
multipers_projects = pd.read_excel('100-projects-2020.xlsx')
multipers_projects=multipers_projects.fillna(0)
multipers_projects
# Out:
#      No                                         proj_id  \
# 0     1  Projects/9153ae29-0fe7-4fe3-a23c-76bebdba50fc
# 1     2  Projects/46ed9347-3cbe-4c02-a3cd-7fc3fd87ba34
# 2     3  Projects/02233e33-dc7e-411b-90e3-742aa1e552e9
# 3     4  Projects/60b7482b-5b3d-49e8-8d4b-ba614a0050da
# 4     5  Projects/26883cbb-d997-4178-ae5d-646e327f3aed
# ..  ...                                             ...
# 95   96  Projects/aaa9de7b-72a2-4110-b70c-7e6fe08915e6
# 96   97  Projects/3a525153-9fbc-4fef-88d6-d7027262261c
# 97   98  Projects/7a8539e2-93ad-4864-a4c7-405ec848fdd4
# 98   99  Projects/1b14218b-14e7-444d-abc5-1e8c4eef2f8a
# 99  100  Projects/8fc79d73-79df-47d3-a38f-fba822476f9c
#
#                                                 title  people
# 0    Data-driven energy systems modeling for cost-...       2
# 1    Genetic and demographic research on fire sala...       3
# 2    A journey of Hope: In search of a critical sp...       2
# ...

# %%
valid_ids=[]
for i in range(multipers_projects.shape[0]):
    if multipers_projects['proj_id'][i] != 0:
        valid_ids=valid_ids+[multipers_projects['proj_id'][i]]
        
path= r'C:\Users\lucp11051\PycharmProjects\idr\df_maker_input_output/'

np.savetxt(path + 'multipers_ids.txt', valid_ids, fmt= '%s')
